# %% [markdown]
# # CS 2302 - Quiz 11 - Graphs 2

# %% [markdown]
# ## **Before you start**
#
# Make a copy of this Colab by clicking on File > Save a Copy in Drive

# %%
student_name = "Salvador Robles Herrera"
student_id = "80683116"

# %% [markdown]
# ### [50 points] Problem 1
#
# Trace the execution of Kruskal’s and Prim’s Minimum Spanning tree algorithms using the following graph as input. When tracing Prim's algorithm, start with vertex 0.
#
# ![Screen Shot 2020-11-11 at 10.13.46 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![125214581_372648183970879_1561957791610851952_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### [50 points] Problem 2
#
# Using the graph below, trace the execution of breadth first search and depth first search using vertex 0 as the origin.
#
# ![Screen Shot 2020-11-11 at 10.13.58 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![125420102_1061576230961193_5974942666142486465_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## How to Submit
#
# 1. File > Download .ipynb
# 2. Go to Blackboard, find the submission page, and upload the .ipynb file you just downloaded.
