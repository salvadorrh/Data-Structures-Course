# %% [markdown]
# # CS 2302 - Quiz 12 - Graphs 3

# %% [markdown]
# ## **Before you start**
#
# Make a copy of this Colab by clicking on File > Save a Copy in Drive

# %%
student_name = "Salvador Robles Herrera"
student_id = "80683116"

# %% [markdown]
# ### [50 points] Problem 1
#
# Trace the execution of Dijkstra’s algorithm. Source = 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![126180973_407737647020443_298630525905996888_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### [50 points] Problem 2
#
# Trace the execution of topological sort.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![126208087_568420557332758_5285992815141954161_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## How to Submit
#
# 1. File > Download .ipynb
# 2. Go to Blackboard, find the submission page, and upload the .ipynb file you just downloaded.
